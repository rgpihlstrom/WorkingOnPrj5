# %%
#import Libraries
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import Chrome
import pandas as pd
import time
from selenium.webdriver.common.keys import Keys


# path={'ENTER PATH TO CHROMEDRIVER ON YOUR COMPUTER'}
# path='/Users/rgpih/Documents/Flatiron/selenium/drivers'
#Use Incognito mode when scraping

chrome_options = Options()
chrome_options.add_argument(" — incognito")

# %%
def checkifThereisavalue(element):
    if len(element):
        result = element[0].text
    else:
        result = "Nothing"
    return result


def checkifThereisanImage(element):
    if len(element):
        result = element[0].get_attribute('src')
    else:
        result = "Nothing"
    return result

# %% [markdown]
# # Target

# %%
browser=webdriver.Chrome(executable_path="../drivers/chromedriver.exe")
    

# df_urlFile = pd.read_csv("C:\\Users\\rgpih\\Documents\\WebScraping\\scrapy\\projects\\amazon2\\AmazonUrls.csv")
# df_targeturls = df_urlFile[df_urlFile["Target"]=="Target"]["URL"]



# df=pd.DataFrame(columns=['reviewname','reviewTitles','postDate','starRating', 'reviewBody','verified','helpful',
#                          'page','Product','Source','UPC','reviewerProfilerUrl','images', 'taste', 'quality', 'value', 'wouldReccomend'])

Producturl ='https://www.target.com/p/beyond-meat-burger-2pk-4oz-patties/-/A-53332974#lnk=sametab'
Scrolldown = 0
i = 0
LoadBttnAvialable = True
#for Producturl in df_targeturls
if Producturl:
    Cururl = Producturl
else:
    Cururl = Cururl

while Cururl  != "Stop":
    browser.get(Cururl)
    time.sleep(5)
    i = i +1
    print(f'Loop: {i}')

#         reviews = browser.find_elements_by_xpath("//div[@class='Grid ReviewList-content']")
# #         print(f'Number of Reviews: {len(reviews)}')

#         for review in reviews:
#             data={}
#             starContainer = review.find_element_by_xpath(".//span[@class='stars-container']")
#             #print(f' Number of star containers: {len(starContainer)}')

#             fullStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-small star-rated elc-icon-star-rating']"))
#             #print(f' Number of full stars: {(fullStarsCount)}')

#             emptyStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-small star-empty elc-icon-star-rating']"))
#             #print(f' Number of empty stars: {(emptyStarsCount)}')

#             partialStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-medium star-partial elc-icon-star-rating']"))
#             #print(f' Number of partial stars: {(partialStarsCount)}')
#             numberOfStars = fullStarsCount+partialStarsCount

#             data['reviewTitles'] = checkifThereisavalue(review.find_elements_by_xpath('.//h3[@itemprop="name"]'))
#             data['starRating'] = numberOfStars
#             data['postDate'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@itemprop="datePublished"]'))
#             data['reviewBody'] = checkifThereisavalue(review.find_elements_by_xpath('.//div[@class="review-text"]/p'))
#             data['images'] = checkifThereisanImage(review.find_elements_by_xpath('.//img[@class="review-media-thumbnail"]'))
#             data['reviewname'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@itemprop="author"]'))
#             data['helpful'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@class="yes-no-count underline"]'))
#             data['Product'] = checkifThereisavalue(browser.find_elements_by_xpath('//h2[@class="prod-ProductTitle no-margin truncated wyr-product-title font-normal hide-content-max-s heading-b"]'))
#             data['page'] = browser.current_url
#             data['source'] = "https://www.walmart.com/reviews/product"
#             data['reviewerProfilerUrl'] = "Nothing"
#             df=df.append(data, ignore_index=True)
#     time.sleep(2)
#     html = browser.find_element_by_tag_name('html')
#     html.send_keys(Keys.END)
    
    
    
    last_height = browser.execute_script("return document.documentElement.scrollHeight")
    print(f'Last height :{last_height}')
    
    Scrolldown = 3500
    if i == 1:
        Scrolldown = Scrolldown + 3500
    else:
        Scrolldown = Scrolldown + 25
    
    scrolldownstring = 'window.scrollTo(0, window.scrollY + ' + str(Scrolldown) + ')'
    print(f' Scrolldownstring: {scrolldownstring}')
    
#     browser.execute_script("window.scrollTo(0, window.scrollY + 3000)")
    browser.execute_script(scrolldownstring)
    time.sleep(2)
    
    nexturl = checkifThereisavalue(browser.find_elements_by_xpath("//div[@data-test='load-more-btn']/button[@class='Button-bwu3xu-0 iTtldf']"))
    time.sleep(2)
    print(nexturl)
    if nexturl != "Nothing":
        browser.find_elements_by_xpath("//div[@data-test='load-more-btn']/button[@class='Button-bwu3xu-0 iTtldf']")[0].click()
        Cururl = browser.current_url
        newhieght = browser.execute_script("return document.documentElement.scrollHeight")
        print(f'New height: {newhieght}')
    else:
        Cururl = "Stop"   



# for Producturl in df_walmarturls:
    
#     if Producturl:
#         Cururl = Producturl
#     else:
#         Cururl = Cururl
        
#     while Cururl != "Stop":
#         browser.get(Cururl)
#         time.sleep(5)

#         reviews = browser.find_elements_by_xpath("//div[@class='Grid ReviewList-content']")
# #         print(f'Number of Reviews: {len(reviews)}')

#         for review in reviews:
#             data={}
#             starContainer = review.find_element_by_xpath(".//span[@class='stars-container']")
#             #print(f' Number of star containers: {len(starContainer)}')

#             fullStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-small star-rated elc-icon-star-rating']"))
#             #print(f' Number of full stars: {(fullStarsCount)}')

#             emptyStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-small star-empty elc-icon-star-rating']"))
#             #print(f' Number of empty stars: {(emptyStarsCount)}')

#             partialStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-medium star-partial elc-icon-star-rating']"))
#             #print(f' Number of partial stars: {(partialStarsCount)}')
#             numberOfStars = fullStarsCount+partialStarsCount

#             data['reviewTitles'] = checkifThereisavalue(review.find_elements_by_xpath('.//h3[@itemprop="name"]'))
#             data['starRating'] = numberOfStars
#             data['postDate'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@itemprop="datePublished"]'))
#             data['reviewBody'] = checkifThereisavalue(review.find_elements_by_xpath('.//div[@class="review-text"]/p'))
#             data['images'] = checkifThereisanImage(review.find_elements_by_xpath('.//img[@class="review-media-thumbnail"]'))
#             data['reviewname'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@itemprop="author"]'))
#             data['helpful'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@class="yes-no-count underline"]'))
#             data['Product'] = checkifThereisavalue(browser.find_elements_by_xpath('//h2[@class="prod-ProductTitle no-margin truncated wyr-product-title font-normal hide-content-max-s heading-b"]'))
#             data['page'] = browser.current_url
#             data['source'] = "https://www.walmart.com/reviews/product"
#             data['reviewerProfilerUrl'] = "Nothing"
#             df=df.append(data, ignore_index=True)
#         nexturl = checkifThereisavalue(browser.find_elements_by_xpath("//button[@class='paginator-btn paginator-btn-next']"))
#         if nexturl != "Nothing":
#             browser.find_elements_by_xpath("//button[@class='paginator-btn paginator-btn-next']")[0].click()
#             Cururl = browser.current_url
#         else:
#             Cururl = "Stop"
# Out:
# Loop: 1
# Last height :4363
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 7000)
# Load 8 more
# New height: 8654
# Loop: 2
# Last height :5412
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8839
# Loop: 3
# Last height :5393
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 11545
# Loop: 4
# Last height :5356
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8783
# Loop: 5
# Last height :5283
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8710
# Loop: 6
# Last height :5393
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8820
# Loop: 7
# Last height :5320
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8747
# Loop: 8
# Last height :5356
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 11508
# Loop: 9
# Last height :5198
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8625
# Loop: 10
# Last height :5393
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 11545
# Loop: 11
# Last height :5338
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8765
# Loop: 12
# Last height :5356
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8783
# Loop: 13
# Last height :5356
#  Scrolldownstring: window.scrollTo(0, window.scrollY + 3525)
# Load 8 more
# New height: 8783
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-210eb6c52ce9> in <module>
#      21
#      22 while Cururl  != "Stop":
# ---> 23     browser.get(Cururl)
#      24     time.sleep(5)
#      25     i = i +1
#
# ~\anaconda3a\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3a\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\anaconda3a\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\anaconda3a\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\anaconda3a\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77             )
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#
# ~\anaconda3a\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3a\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3a\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3a\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3a\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3a\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3a\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\anaconda3a\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\anaconda3a\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\anaconda3a\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
nexturl = checkifThereisavalue(browser.find_elements_by_xpath("//button[@class='Button-bwu3xu-0 iTtldf']"))
nexturl
# Out:
# 'Load 8 more'

# %%
browser.find_elements_by_xpath("//button[@class='Button-bwu3xu-0 iTtldf']")[0].click()

# %% [markdown]
# # Walmart

# %%
df_urlFile = pd.read_csv("C:\\Users\\rgpih\\Documents\\WebScraping\\scrapy\\projects\\amazon2\\AmazonUrls.csv")
df_walmarturls = df_urlFile[df_urlFile["Target"]=="Walmart"]["URL"]


# url = 'https://www.walmart.com/reviews/product/957733881'
df=pd.DataFrame(columns=['reviewname','reviewTitles','postDate','starRating', 'reviewBody','verified','helpful','page','Product','Source','UPC','reviewerProfilerUrl','images'])

for Producturl in df_walmarturls:
    
    if Producturl:
        Cururl = Producturl
    else:
        Cururl = Cururl
        
    while Cururl != "Stop":
        browser.get(Cururl)
        time.sleep(5)

        reviews = browser.find_elements_by_xpath("//div[@class='Grid ReviewList-content']")
#         print(f'Number of Reviews: {len(reviews)}')

        for review in reviews:
            data={}
            starContainer = review.find_element_by_xpath(".//span[@class='stars-container']")
            #print(f' Number of star containers: {len(starContainer)}')

            fullStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-small star-rated elc-icon-star-rating']"))
            #print(f' Number of full stars: {(fullStarsCount)}')

            emptyStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-small star-empty elc-icon-star-rating']"))
            #print(f' Number of empty stars: {(emptyStarsCount)}')

            partialStarsCount = len(starContainer.find_elements_by_xpath(".//span[@class='elc-icon star star-medium star-partial elc-icon-star-rating']"))
            #print(f' Number of partial stars: {(partialStarsCount)}')
            numberOfStars = fullStarsCount+partialStarsCount

            data['reviewTitles'] = checkifThereisavalue(review.find_elements_by_xpath('.//h3[@itemprop="name"]'))
            data['starRating'] = numberOfStars
            data['postDate'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@itemprop="datePublished"]'))
            data['reviewBody'] = checkifThereisavalue(review.find_elements_by_xpath('.//div[@class="review-text"]/p'))
            data['images'] = checkifThereisanImage(review.find_elements_by_xpath('.//img[@class="review-media-thumbnail"]'))
            data['reviewname'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@itemprop="author"]'))
            data['helpful'] = checkifThereisavalue(review.find_elements_by_xpath('.//span[@class="yes-no-count underline"]'))
            data['Product'] = checkifThereisavalue(browser.find_elements_by_xpath('//h2[@class="prod-ProductTitle no-margin truncated wyr-product-title font-normal hide-content-max-s heading-b"]'))
            data['page'] = browser.current_url
            data['source'] = "https://www.walmart.com/reviews/product"
            data['reviewerProfilerUrl'] = "Nothing"
            df=df.append(data, ignore_index=True)
        nexturl = checkifThereisavalue(browser.find_elements_by_xpath("//button[@class='paginator-btn paginator-btn-next']"))
        if nexturl != "Nothing":
            browser.find_elements_by_xpath("//button[@class='paginator-btn paginator-btn-next']")[0].click()
            Cururl = browser.current_url
        else:
            Cururl = "Stop"

# %%
df.shape

# %%
df.to_excel("WalmartReviews.xlsx")
